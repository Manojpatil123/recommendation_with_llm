# %%
import pandas as pd

# %%
df=pd.read_excel(r'D:\Recommendation-systems-with-LLMs-main\Recommendation-systems-with-LLMs-main\Listado de Documentación Corporativa 11SEP.xlsx')

# %%
df1=df.iloc[:,0:4]

# %%
df1.rename({'Código':'Procedure id','Título en español':'Procedure title(spanish)','Título en inglés':'Procedure title(english)','Rev':'Procedure revision'},axis=1,inplace=True)

# %%
df1.head(50)
# Out:
#    Procedure id                           Procedure title(spanish)  \
# 0         PG-10        COMPETENCIA, FORMACIÓN Y TOMA DE CONCIENCIA
# 1         PG-22  REVISIÓN DEL SISTEMA DE GESTIÓN DE SEGURIDAD D...
# 2         PG-26                            OBJETIVOS E INDICADORES
# 3         PG-27   REVISIÓN DE LA EFECTIVIDAD DE CONTROLES DEL SGSI
# 4         PG-29                                                NaN
# 5        PGA-01  IDENTIFICACIÓN Y EVALUACIÓN DE LOS ASPECTOS E ...
# 6        PGA-02                     GESTIÓN DE RESIDUOS Y CONSUMOS
# 7        PGC-01                                                NaN
# 8        PGC-02                                                NaN
# 9        PGC-03                                                NaN
# 10       PGS-01  AUDITORÍAS INTERNAS AL SISTEMA DE GESTIÓN DE S...
# 11       PGS-03  TRATAMIENTO DE NO CONFORMIDADES Y ACCIONES COR...
# 12       PGS-04                     PLAN DE CONTINUIDAD DE NEGOCIO
# ...

# %%
df1['Procedure title(english)'].fillna(df1['Procedure title(spanish)'], inplace=True)

# %%
df1.drop(['Procedure title(spanish)'],axis=1,inplace=True)

# %%
df1
# Out:
#        Procedure id                           Procedure title(english)  \
# 0             PG-10                 COMPETENCE, TRAINING AND AWARENESS
# 1             PG-22    INFORMATION SECURITY MANAGEMENT SYSTEM REVISION
# 2             PG-26                          OBJECTIVES AND INDICATORS
# 3             PG-27     REVISION OF THE EFFECTIVENESS OF ISMS CONTROLS
# 4             PG-29            INFORMATION SECURITY COMMUNICATION PLAN
# ...             ...                                                ...
# 2153  N-ITG-090-504     RECORDS CONTROL IN NUCLEAR FACILITIES PROJECTS
# 2154  N-ITG-090-505  CONTROL OF THE DESIGN SOFTWARE IN NUCLEAR FACI...
# 2155        N-PG-01      QUALITY AUDITS IN NUCLEAR FACILITIES PROJECTS
# 2156        N-PG-11  TREATMENT OF NON CONFORMITIES, CORRECTIVE AND ...
# 2157    PCO-156-001  STORAGE, CONTROL AND PRESERVATION OF MATERIALS...
#
#       Procedure revision
# 0                     17
# 1                      1
# 2                      2
# ...

# %%
df1['Procedure revision']=df1['Procedure revision'].astype('str')

# %%
df1['procedures']='Procedure id : '+df1['Procedure id'] +'\n\n'+'Procedure title : '+df1['Procedure title(english)'] +'\n\n'+'Procedure revision : '+df1['Procedure revision']+'\n'

# %%
print(df1['procedures'][0])
# Out:
# Procedure id : PG-10
#
# Procedure title : COMPETENCE, TRAINING AND AWARENESS
#
# Procedure revision : 17

# %%
df1.drop(['Procedure id','Procedure title(english)','Procedure revision'],axis=1,inplace=True)

# %%
df1
# Out:
#                                              procedures
# 0     Procedure id : PG-10\n\nProcedure title : COMP...
# 1     Procedure id : PG-22\n\nProcedure title : INFO...
# 2     Procedure id : PG-26\n\nProcedure title : OBJE...
# 3     Procedure id : PG-27\n\nProcedure title : REVI...
# 4     Procedure id : PG-29\n\nProcedure title : INFO...
# ...                                                 ...
# 2153  Procedure id : N-ITG-090-504\n\nProcedure titl...
# 2154  Procedure id : N-ITG-090-505\n\nProcedure titl...
# 2155  Procedure id : N-PG-01\n\nProcedure title : QU...
# 2156  Procedure id : N-PG-11\n\nProcedure title : TR...
# 2157  Procedure id : PCO-156-001\n\nProcedure title ...
#
# [2158 rows x 1 columns]

# %%
import os

# %%
BASE_DIR = os.getcwd()

# %%
df1.to_csv(BASE_DIR +'\data1\output.csv')
